# %%
import pandas as pd
import numpy as np
import re
from requests.exceptions import ReadTimeout, ConnectTimeout
import requests

# %%
a=pd.read_excel(r"C:\Users\49653\Desktop\yx\data\data.xlsx",encoding='utf-8')

# %%
a1=a["事故地点"]
a1=list(a1)
for i in range(len(a1)):
    a1[i]='上海市'+a1[i]

# %%
def geocode(address):  ## 获取对应道路的经纬度
    parameters = {'address': address, 'key': '3703bcae3e5796a7dbec9ae61ed21d03'}
    base = 'http://restapi.amap.com/v3/geocode/geo'
    response = requests.get(base, parameters)
    answer = response.json()
    # if answer['count'] == '0':
    #     return "error", "", "", ""
    # dz = answer['geocodes'][0]['formatted_address']
    # qu = answer['geocodes'][0]['city'] + answer['geocodes'][0]['district']
    # adcode = answer['geocodes'][0]['adcode']
    # location = answer['geocodes'][0]['location']
    try:
        location=answer['geocodes'][0]['location']
    except:
        location=['0']
    return answer,location

# %%
geocode('上海市浦东新区水华路上海电机学院')
# Out:
# ({'status': '1',
#   'info': 'OK',
#   'infocode': '10000',
#   'count': '1',
#   'geocodes': [{'formatted_address': '上海市浦东新区上海电机学院',
#     'country': '中国',
#     'province': '上海市',
#     'citycode': '021',
#     'city': '上海市',
#     'district': '浦东新区',
#     'township': [],
#     'neighborhood': {'name': [], 'type': []},
#     'building': {'name': [], 'type': []},
#     'adcode': '310115',
#     'street': [],
#     'number': [],
#     'location': '121.885397,30.888630',
#     'level': '兴趣点'}]},
#  '121.885397,30.888630')

# %%
a2=[]
for i in range(len(a1)):  
    a2.append(geocode(a1[i]))

# %%
new=pd.DataFrame(columns=['name','jingweidu'])
new['name']=a1
new['jingweidu']=a2

# %%
new.to_csv('new.csv',encoding='utf-8')

# %%
a=pd.read_excel(r"C:\Users\49653\Desktop\yx\data\data.xlsx",encoding='utf-8')

# %%
a
# Out:
#                    事故编号  事故形态            事故地点              事故发生日期
# 0    310101420190004101    11    长乐路成都南路北约50米    2019/9/1 0:45:00
# 1    310101420190004100    11    西藏南路淮海东路北约6米    2019/9/1 4:44:00
# 2    310101420190004153    11   陕西南路出进贤路南约10米   2019/9/1 10:18:00
# 3    310101420190004121    11  斜土东路出制造局路东约60米   2019/9/1 11:09:00
# 4    310101420190004123    36    白渡路中华路东南约25米   2019/9/1 11:45:00
# ..                  ...   ...             ...                 ...
# 194  310101420190004599    11   斜土路进蒙自路东约100米  2019/9/30 15:23:00
# 195  310101420190004600    11     牛庄路云南北路东约3米  2019/9/30 21:15:00
# 196  310101420190004696    11  光启南路进复兴东路南约50米  2019/9/30 22:37:00
# 197  310101420190004607    35    六合路宁波路西南约15米  2019/10/1 15:30:00
# 198  310101420190004665    11     广东路广西北路东约3米  2019/10/1 15:49:00
#
# [199 rows x 4 columns]

# %%
a1=a["事故地点"]
a1=list(a1)
for i in range(len(a1)):
    a1[i]='上海市'+a1[i]
a2=a['事故形态']
a1=list(a1)
a2=list(a2)

# %%
a11=[]
a22=[]
a33=[]
for i in range(len(a1)):
    if(str(a2[i])[0]=='1'):
        a11.append(a1[i])
    elif(str(a2[i])[0]=='2'):
        a22.append(a1[i])
    else:
        a33.append(a1[i])

# %%
a111=[]
a222=[]
a333=[]
for i in range(len(a11)):  
    a111.append(geocode(a11[i]))

# %%
for i in range(len(a22)):  
    a222.append(geocode(a22[i]))
for i in range(len(a33)):  
    a333.append(geocode(a33[i]))

# %%
new1=pd.DataFrame(columns=['name','jingweidu'])
new2=pd.DataFrame(columns=['name','jingweidu'])
new3=pd.DataFrame(columns=['name','jingweidu'])
new1['name']=a11
new1['jingweidu']=a111
new2['name']=a22
new2['jingweidu']=a222
new3['name']=a33
new3['jingweidu']=a333

# %%
new1.to_csv('new1.csv',encoding='utf-8')
new2.to_csv('new2.csv',encoding='utf-8')
new3.to_csv('new3.csv',encoding='utf-8')

# %%
dict = {'name': a11, 'value':11}

# %%
atest=['']
for i in range(len(a11)):
    atest[0]+=' { name:'+a11[i]+', value:  '+15+'},'

# %%
w=0
with open('atest.txt','w',encoding='utf-8')as f:
    
    for i in range(len(a11)):
        w+=1
        f.write('{ name: "'+a11[i]+'", value:  '+str(15)+'},')
        f.write('\n')
    for i in range(len(a22)):
        f.write('{ name: "'+a22[i]+'", value:  '+str(25)+'},')
        f.write('\n')
    for i in range(len(a33)):
        f.write('{ name: "'+a33[i]+'", value:  '+str(35)+'},')
        f.write('\n')

# %%
with open('atest1.txt','w',encoding='utf-8')as f:
    for i in range(len(a111)):
        f.write(' '+a11[i]+': ['+a111[i]+'],')
        f.write('\n')
    for i in range(len(a222)):
        f.write(' '+a22[i]+': ['+a222[i]+'],')
        f.write('\n')
    for i in range(len(a333)):
        f.write(' '+a33[i]+': ['+a333[i]+'],')
        f.write('\n')

# %%
var data = [
{ name: "上海市长乐路成都南路北约50米", value:  120},
{ name: "上海市西藏南路淮海东路北约6米", value:  120},
{ name: "上海市陕西南路出进贤路南约10米", value:  120},
{ name: "上海市斜土东路出制造局路东约60米", value:  120},
{ name: "上海市九江路进西藏中路西约80米", value:  120},
{ name: "上海市延安东路黄陂北路南约01米", value:  120},
{ name: "上海市瞿溪路出局门路东约30米", value:  120},
{ name: "上海市丽园路鲁班路东约0米", value:  120},
{ name: "上海市鲁班路南塘浜路南约10米", value:  120},
{ name: "上海市浙江中路进牛庄路北约15米", value:  120},
{ name: "上海市人民路进方浜中路北约50米", value:  120},
{ name: "上海市南昌路进思南路东约100米", value:  120},
{ name: "上海市徐家汇路肇周路西约15米", value:  120},
{ name: "上海市鲁班路斜土路东约0米", value:  120},
{ name: "上海市鲁班路中山南一路南约0米", value:  120},
{ name: "上海市北京东路福建中路西约5米", value:  120},
{ name: "上海市打浦路隧道", value:  120},
{ name: "上海市延安东路成都北路西北约5米", value:  120},
{ name: "上海市延安东路黄陂北路西约6米", value:  120},
{ name: "上海市长乐路陕西南路东约15米", value:  120},
{ name: "上海市西藏南路复兴东路南约6米", value:  120},
{ name: "上海市打浦路隧道", value:  120},
{ name: "上海市建国东路淡水路东约00米", value:  120},
{ name: "上海市河南南路尚文路西北约2米", value:  120},
{ name: "上海市人民路枫泾路东南约5米", value:  120},
{ name: "上海市福州路山西南路西南约20米", value:  120},
{ name: "上海市九江路出西藏中路西约250米", value:  120},
{ name: "上海市西藏南路金陵中路西南约5米", value:  120},
{ name: "上海市中华路复兴东路西南约5米", value:  120},
{ name: "上海市金陵东路进云南南路西约50米", value:  120},
{ name: "上海市马当路淮海中路南约01米", value:  120},
{ name: "上海市自忠路吉安路东约01米", value:  120},
{ name: "上海市长乐路进茂名南路西约150米", value:  120},
{ name: "上海市鲁班路徐家汇路北约0米", value:  120},
{ name: "上海市瑞金二路肇嘉浜路西北约20米", value:  120},
{ name: "上海市南仓街进陆家浜路北约80米", value:  120},
{ name: "上海市延安东路福建中路东约0米", value:  120},
{ name: "上海市打浦路徐家汇路东约0米", value:  120},
{ name: "上海市建国中路思南路西约50米", value:  120},
{ name: "上海市半淞园路保屯路西约30米", value:  120},
{ name: "上海市延安东路隧道南线", value:  120},
{ name: "上海市南京西路黄河路北约5米", value:  120},
{ name: "上海市制造局路斜土东路北约30米", value:  120},
{ name: "上海市重庆南路徐家汇路北约10米", value:  120},
{ name: "上海市西藏南路复兴东路北约20米", value:  120},
{ name: "上海市茂名南路长乐路东约10米", value:  120},
{ name: "上海市福建中路宁波路北北约5米", value:  120},
{ name: "上海市昼锦路河南南路东约150米", value:  120},
{ name: "上海市西藏南路陆家浜路西约6米", value:  120},
{ name: "上海市思南路南昌路东约2米", value:  120},
{ name: "上海市斜土路打浦路东约6米", value:  120},
{ name: "上海市湖北路汉口路东约6米", value:  120},
{ name: "上海市西藏南路中山南路南约6米", value:  120},
{ name: "上海市河南南路复兴东路南约6米", value:  120},
{ name: "上海市河南南路人民路南约5米", value:  120},
{ name: "上海市延安东路西藏中路西约0米", value:  120},
{ name: "上海市陆家浜路海潮路西约0米", value:  120},
{ name: "上海市鲁班路丽园路东约15米", value:  120},
{ name: "上海市复兴中路思南路东约5米", value:  120},
{ name: "上海市汉口路浙江中路西南约20米", value:  120},
{ name: "上海市安仁街进人民路南约30米", value:  120},
{ name: "上海市延安东路隧道北线", value:  120},
{ name: "上海市云南南路出金陵东路北约40米", value:  120},
{ name: "上海市延安东路隧道北线出陆家嘴环路西约50米", value:  120},
{ name: "上海市建国西路出陕西南路东约200米", value:  120},
{ name: "上海市中华路光启南路东约01米", value:  120},
{ name: "上海市重庆南路徐家汇路北约01米", value:  120},
{ name: "上海市瑞金一路进淮海中路北约0米", value:  120},
{ name: "上海市云南中路广东路北约0米", value:  120},
{ name: "上海市凤阳路出长沙路东约10米", value:  120},
{ name: "上海市芝罘路贵州路东约7米", value:  120},
{ name: "上海市南浦大桥二圈半东向西", value:  120},
{ name: "上海市露香园路人民路南约30米", value:  120},
{ name: "上海市建国西路陕西南路东约60米", value:  120},
{ name: "上海市兴安路嵩山路西约10米", value:  120},
{ name: "上海市制造局路瞿溪路北约20米", value:  120},
{ name: "上海市西藏南路宁海东路北约20米", value:  120},
{ name: "上海市建国中路瑞金二路东南约5米", value:  120},
{ name: "上海市新昌路南京西路北约50米", value:  120},
{ name: "上海市西藏南路复兴东路北约10米", value:  120},
{ name: "上海市河南中路南京东路南约10米", value:  120},
{ name: "上海市人民路方浜中路西约5米", value:  120},
{ name: "上海市外咸瓜街进东门路南约45米", value:  120},
{ name: "上海市半淞园路进望达路西约30米", value:  120},
{ name: "上海市紫霞路进外郎家桥街东约50米", value:  120},
{ name: "上海市瑞金二路绍兴路南约10米", value:  120},
{ name: "上海市金陵东路广西南路南约0米", value:  120},
{ name: "上海市肇周路大吉路北约30米", value:  120},
{ name: "上海市淡水路出太仓路北约25米", value:  120},
{ name: "上海市陆家浜路进外马路西约30米", value:  120},
{ name: "上海市太仓路马当路东北约5米", value:  120},
{ name: "上海市浙江南路出人民路北约20米", value:  120},
{ name: "上海市复兴东路出三牌楼路东西约35米", value:  120},
{ name: "上海市淮海东路云南南路西北约5米", value:  120},
{ name: "上海市南苏州路出河南中路西约50米", value:  120},
{ name: "上海市西藏中路出凤阳路北约35米", value:  120},
{ name: "上海市徐家汇路出打浦路东约80米", value:  120},
{ name: "上海市外郎家桥街毛家园路东北约5米", value:  120},
{ name: "上海市贵州路九江路东约01米", value:  120},
{ name: "上海市复兴中路进思南路西约40米", value:  120},
{ name: "上海市鲁班路出南塘浜路北约100米", value:  120},
{ name: "上海市西藏南路方斜路南约0米", value:  120},
{ name: "上海市中山南路东门路东南约0米", value:  120},
{ name: "上海市兴安路黄陂南路南约0米", value:  120},
{ name: "上海市成都北路延安东路北约10米", value:  120},
{ name: "上海市延安东路成都北路南约0米", value:  120},
{ name: "上海市湖北路广东路东约0米", value:  120},
{ name: "上海市广西北路进汉口路南约30米", value:  120},
{ name: "上海市复兴中路茂名南路西约10米", value:  120},
{ name: "上海市大境路露香园路东约0米", value:  120},
{ name: "上海市南仓街陆家浜路北约0米", value:  120},
{ name: "上海市茂名南路淮海中路北约50米", value:  120},
{ name: "上海市黄陂南路淮海中路南约50米", value:  120},
{ name: "上海市芝罘路贵州路南约0米", value:  120},
{ name: "上海市太仓路进马当路西约50米", value:  120},
{ name: "上海市新闸路乌镇路桥北约0米", value:  120},
{ name: "上海市建国东路重庆南路东约0米", value:  120},
{ name: "上海市贵州路牛庄路北约0米", value:  120},
{ name: "上海市汉口路广西北路南约0米", value:  120},
{ name: "上海市徐家汇路打浦路西约10米", value:  120},
{ name: "上海市合肥路马当路东约5米", value:  120},
{ name: "上海市建国东路马当路东约50米", value:  120},
{ name: "上海市重庆南路复兴中路北约5米", value:  120},
{ name: "上海市外滩隧道东线东门路南约0米", value:  120},
{ name: "上海市蒙自西路鲁班路西约0米", value:  120},
{ name: "上海市延安东路西藏中路东约0米", value:  120},
{ name: "上海市凤阳路六合路西约0米", value:  120},
{ name: "上海市西藏南路肇周路西约0米", value:  120},
{ name: "上海市河南南路复兴东路东约2米", value:  120},
{ name: "上海市建国东路淡水路北约5米", value:  120},
{ name: "上海市四川中路出福州路北约15米", value:  120},
{ name: "上海市重庆中路延安东路西南约10米", value:  120},
{ name: "上海市打浦路进斜土路北约10米", value:  120},
{ name: "上海市茂名南路长乐路北约5米", value:  120},
{ name: "上海市四川中路出香港路南约75米", value:  120},
{ name: "上海市新闸路北京西路西约3米", value:  120},
{ name: "上海市打浦路进瞿溪路南约50米", value:  120},
{ name: "上海市人民路浙江南路南约01米", value:  120},
 上海市河南南路复兴东路北约25米: [121.489969,31.221756],
 上海市南仓街多稼路北约5米: [121.500485,31.212824],
 上海市延安东路进重庆北路东约50米: [121.470347,31.225146],
 上海市蒙自路蒙自西路东约0米: [121.476986,31.207779],
 上海市人民路浙江南路北约20米: [121.483763,31.227076],
 上海市复兴东路中华路东东约30米: [121.499053,31.220938],
 上海市丽园路西藏南路东约10米: [121.486776,31.210082],
 上海市徐家汇路进黄陂南路东约33米: [121.476050,31.218303],
 上海市复兴东路进河南南路东约6米: [121.489969,31.221756],
 上海市斜土路进蒙自路东约100米: [121.480808,31.200165],
 上海市牛庄路云南北路东约3米: [121.475166,31.237014],
 上海市光启南路进复兴东路南约50米: [121.494274,31.221906],
 上海市广东路广西北路东约3米: [121.478984,31.231171],
 上海市温州路新闸路北约0米: [121.469510,31.238519],
 上海市光启南路进复兴东路南约50米: [121.494274,31.221906],
 上海市黄陂北路进江阴路北约10米: [121.471169,31.228898],
 上海市复兴东路中华路东西约0米: [121.499053,31.220938],
 上海市浙江中路厦门路南约5米: [121.476568,31.239776],
 上海市丽园路进局门路东约100米: [121.474898,31.204976],
 上海市永宁街学前街西约20米: [121.489497,31.216054],
 上海市河南中路南京东路南约6米: [121.484959,31.237608],
 上海市斜土路鲁班路东约15米: [121.475189,31.203040],
 上海市建国西路出瑞金二路东约200米: [121.466671,31.208518],
 上海市丽园路制造局路西约50米: [121.483357,31.208771],
 上海市方斜路大吉路北约20米: [121.482614,31.213365],
 上海市中山东一路滇池路东约5米: [121.489997,31.239309],
 上海市福州路西藏中路东约5米: [121.476357,31.231550],
 上海市丽园路出制造局路西约80米: [121.483357,31.208771],
 上海市长乐路成都南路东约00米: [121.467617,31.221925],
 上海市方斜路陆家浜路北约11米: [121.483099,31.211497],
 上海市大吉路西藏南路东约30米: [121.485267,31.214510],
 上海市中华路金坛路南约0米: [121.498501,31.218872],
 上海市河南中路延安东路北约6米: [121.486615,31.231183],
 上海市西藏南路大林路北约0米: [121.485817,31.212603],
 上海市普安路桃源路北约80米: [121.477854,31.223817],
 上海市复兴中路出瑞金二路西约50米: [121.465156,31.214860],
 上海市方浜中路出人民路东约7米: [121.489175,31.224437],
 上海市瞿溪路西藏南路西约50米: [121.488635,31.203733],
 上海市瑞金二路进永嘉路东约20米: [121.464587,31.215819],
 上海市白渡路中华路东南约25米: [121.498807,31.220092],
 上海市复兴中路进思南路东约30米: [121.482674,31.218478],
 上海市西藏南路进高雄路北约50米: [121.481812,31.221244],
 上海市中华路董家渡路东约0米: [121.497917,31.215382],
 上海市复兴东路隧道北线下层: [121.508752,31.223985],
 上海市浙江中路进延安东路北约30米: [121.481510,31.230287],
 上海市徐家汇路进打浦路西约50米: [121.426597,31.188861],
 上海市九江路河南中路西约30米: [121.485168,31.236656],
 上海市丽水路人民路南约5米: [121.490844,31.229493],
 上海市南仓街进陆家浜路南约30米: [121.499938,31.211260],
 上海市六合路宁波路西南约15米: [121.474804,31.236325],
};

var convertData = function (data) {
  var res = [];
  for (var i = 0; i < data.length; i++) {
    var geoCoord = geoCoordMap[data[i].name];
    if (geoCoord) {
      res.push({
        name: data[i].name,
        value: geoCoord.concat(data[i].value)
      });
    }
  }
  return res;
};

var option = {
  // amap component option
  amap: {
    // enable 3D mode
    viewMode: "3D",
    // initial options of AMap
    // See https://lbs.amap.com/api/javascript-api/reference/map#MapOption for details
    // initial map center [lng, lat]
    center: [108.39, 39.9],
    // initial map zoom
    zoom: 4,
    // whether the map and echarts automatically handles browser window resize to update itself.
    resizeEnable: true,
    // customized map style, see https://lbs.amap.com/dev/mapstyle/index for details
    mapStyle: "amap://styles/dark",
    // whether echarts layer should be rendered when the map is moving. Default is true.
    // if false, it will only be re-rendered after the map `moveend`.
    // It's better to set this option to false if data is large.
    renderOnMoving: true,
    // the zIndex of echarts layer for AMap, default value is 2000.
    // deprecated since v1.9.0, use `echartsLayerInteractive` instead.
    // echartsLayerZIndex: 2019,
    // whether echarts layer is interactive. Default value is true
    // supported since v1.9.0
    echartsLayerInteractive: true,
    // whether to enable large mode. Default value is false
    // supported since v1.9.0
    largeMode: false,
    // whether to return map camera state in `amaproam` event.
    // supported since v1.10.0
    returnMapCameraState: true,
    // Note: Please DO NOT use the initial option `layers` to add Satellite/RoadNet/Other layers now.
    // There are some bugs about it, we can use `amap.add` instead.
    // Refer to the codes at the bottom.

    // More initial options...
  },
  tooltip: {
    trigger: "item"
  },
  animation: false,
  series: [
    {
      name: "PM2.5",
      type: "scatter",
      // use `amap` as the coordinate system
      coordinateSystem: "amap",
      // data items [[lng, lat, value], [lng, lat, value], ...]
      data: convertData(data),
      symbolSize: function (val) {
        return val[2] / 10;
      },
      encode: {
        value: 2
      },
      label: {
        formatter: "{b}",
        position: "right",
        show: false
      },
      itemStyle: {
        color: "#00c1de"
      },
      emphasis: {
        label: {
          show: true
        }
      }
    },
    {
      name: "Top 5",
      type: "effectScatter",
      coordinateSystem: "amap",
      data: convertData(
        data
          .sort(function (a, b) {
            return b.value - a.value;
          })
          .slice(0, 6)
      ),
      symbolSize: function (val) {
        return val[2] / 10;
      },
      encode: {
        value: 2
      },
      showEffectOn: "render",
      rippleEffect: {
        brushType: "stroke"
      },
      hoverAnimation: true,
      label: {
        formatter: "{b}",
        position: "right",
        show: true
      },
      itemStyle: {
        color: "rgba(255, 165, 0, 0.8)",
        shadowBlur: 10,
        shadowColor: "#333"
      },
      zlevel: 1
    }
  ]
};
// initialize echart
var chart = echarts.init(document.getElementById("echarts-amap"));
chart.setOption(option);
// listen to AMap roam event
// `returnMapCameraState` should be opened if map camera information is needed
chart.on('amaproam', function(e) {
  console.log(e);
});

// get AMap extension component
var amapComponent = chart.getModel().getComponent('amap');
// get the instance of AMap
var amap = amapComponent.getAMap();
// add some controls provided by AMap.
amap.addControl(new AMap.Scale());
amap.addControl(new AMap.ToolBar());
// add SatelliteLayer and RoadNetLayer to map
// var satelliteLayer = new AMap.TileLayer.Satellite();
// var roadNetLayer = new AMap.TileLayer.RoadNet();
// amap.add([satelliteLayer, roadNetLayer]);
// Add a marker to map
amap.add(new AMap.Marker({
  position: [110, 35]
}));
// Make the overlay layer of AMap interactive
// amapComponent.setEChartsLayerInteractive(false);
